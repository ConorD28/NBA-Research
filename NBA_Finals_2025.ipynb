# %% [markdown]
# <a href="https://colab.research.google.com/github/ConorD28/NBA-Research/blob/main/NBA_Finals_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import math
df = pd.read_csv('Finals_Stats.csv')
inputs = df.iloc[:, :-26]
playoffs = df.iloc[:, -26:]

print(inputs.isnull().sum().sum()) #Check if there are NA values
print(playoffs.isnull().sum().sum())
# Out:
# 0
# 0

# %% [markdown]
# # **Correlation/Scores**

# %%
import scipy.stats
def correlation(dataset, threshold, target): #Function to get Pearson's correlation between input and target
  data = []
  cols = []
  correlations = []
  #corS = 0
  if isinstance(target, np.ndarray):
    target = pd.Series(target)
  for col in dataset.columns:
      #print(dataset.loc[:,col])
      #print(col)
      corS = dataset.loc[:,col].corr(target, method='spearman') # 'kendall'
      corP = dataset.loc[:,col].corr(target)
      if (abs(corP) > threshold) or (abs(corS) > threshold):
        cor2 = max(abs(corP), abs(corS))
        data.append(dataset.loc[:,col]) #make list of columns that meet the threshold
        cols.append(col)
        correlations.append(cor2) #make list of correlations that meet the threshold
  if len(data) == 0:
     return pd.DataFrame()

  df = pd.DataFrame(data)
  df_len = len(df.columns)
  df.insert(df_len, 'corrs', correlations)
  df = df.sort_values(by=df.columns[-1], ascending=False, key = abs)
  df = df.transpose()
  df_corrs = df.iloc[-1:, :]
  df = df.drop(df.tail(1).index)
  return df, df_corrs

# %%
from sklearn.model_selection import train_test_split
from numpy.random.mtrand import random_sample
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV, MultiTaskLassoCV
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
def Scores(y, y_pred):
  MSE = mean_squared_error(y, y_pred)
  MAE = mean_absolute_error(y, y_pred)

  range_y = y.max() - y.min()
  Normalized_RMSE = (np.sqrt(MSE)/abs(range_y))
  Normalized_MAE = (MAE/abs(range_y))
  #print(f'Normalized RMSE:{ Normalized_RMSE:.2f}')
  #print(f'Normalized MAE:{ Normalized_MAE:.2f}')
  #print(f'MAE:{ MAE:.3f}')
  #print(f'RMSE:{ np.sqrt(MSE):.3f}')
  return Normalized_RMSE, Normalized_MAE

# %%
def Predict_Scores(model, X_tr, X_te, y_tr, y_te, t_sc):#, predict_df):
  y_train_pred = model.predict(X_tr)
  #print(y_train_pred)

  if len(y_te) != 0:
    y_test_pred = model.predict(X_te)
  else:
    y_test_pred = pd.DataFrame()
  #print('y test values:')
  #print(y_test_pred)

  #print('after inverse transform, training off by:')
  y_train_pred_transformed = t_sc.inverse_transform(y_train_pred.reshape(-1, 1)) # Reshape y_train_pred
  y_train_pred_transformed = pd.Series(y_train_pred_transformed.flatten())
  y_tr_transformed = t_sc.inverse_transform(y_tr.values.reshape(-1, 1))
  y_tr_transformed = pd.Series(y_tr_transformed.flatten())
  inv_error_tr_transformed = np.abs(y_tr_transformed - y_train_pred_transformed)

  #print('Training Scores:')
  NRMSE_tr, NMAE_tr = Scores(y_tr_transformed, y_train_pred_transformed)

  #print('y training values:')
  #print(y_train_pred_transformed)

  inv_error_test_transformed = 0
  y_te_transformed = 0
  y_test_pred_transformed = 0
  #Test Predictions:
  if len(y_te) != 0:
    y_te_transformed = t_sc.inverse_transform(y_te.reshape(-1, 1))
    y_te_transformed = y_te_transformed.flatten()
    y_test_pred_transformed = t_sc.inverse_transform(y_test_pred.reshape(-1, 1))
    y_test_pred_transformed = y_test_pred_transformed.flatten()
    inv_error_test_transformed = np.abs(y_te_transformed - y_test_pred_transformed)
    #print(y_test_pred_transformed)

  #Predict:
  #predictions = model.predict(predict_df)

  return NRMSE_tr, NMAE_tr, inv_error_tr_transformed, inv_error_test_transformed, y_test_pred_transformed, y_train_pred_transformed#, predictions

# %% [markdown]
# # **ML Tuning Algorithms**

# %%
# !pip install optuna
import optuna
# !pip install joblib
import joblib
from sklearn.model_selection import cross_val_score

# %%
def Ridge_tune(X_train, y_train, cv_choice, num_trials, timeout_choice):
    def objective(trial, cv_runs, X_train, y_train):
      alpha = trial.suggest_float("alpha", 1, 25, log=True)#1e-4, 10.0; Alpha is the regularization strength
      solver = trial.suggest_categorical("solver", ["auto", "svd", "cholesky", "lsqr", "sparse_cg", "sag", "saga"])

      model = Ridge(alpha=alpha, solver=solver, random_state=28)
      score = cross_val_score(model, X_train, y_train, cv=cv_runs, scoring="neg_root_mean_squared_error").mean()
      return -score  # Minimize the MSE

    study = optuna.create_study(direction="minimize")
    study.optimize(lambda trial: objective(trial, cv_choice, X_train, y_train), n_trials=num_trials, timeout=timeout_choice)

    print("Best trial:")
    trial = study.best_trial
    print(f"  Params: {trial.params}")

    best_model = Ridge(**trial.params, random_state=28)
    best_model.fit(X_train, y_train)
    joblib.dump(best_model, 'PPG_Ridge_Finals.pkl')
    return best_model

# %%
def Lasso_tune(X_train, y_train, cv_choice, num_trials, timeout_choice):
  def Lasso_objective(trial, cv_runs, X_train, y_train):
    alpha = trial.suggest_float("alpha", 1e-2, 10, log=True)##1e-4, 10.0;
    max_iter = trial.suggest_int("max_iter", 1000, 10000, step=100)  # Max iterations
    tol = trial.suggest_float("tol", 1e-5, 1e-2, log=True)  # Tolerance for stopping criteria

    model = Lasso(alpha=alpha, max_iter=max_iter, tol=tol, random_state=28)
    score = cross_val_score(model, X_train, y_train, cv=cv_runs, scoring="neg_root_mean_squared_error").mean()
    return -score  # Minimize the MSE

  study = optuna.create_study(direction="minimize")
  study.optimize(lambda trial: Lasso_objective(trial, cv_choice, X_train, y_train), n_trials=num_trials, timeout=timeout_choice)
  print("Best trial:")
  trial = study.best_trial
  print(f"  Params: {trial.params}")

  best_model = Lasso(**trial.params, random_state=28)
  best_model.fit(X_train, y_train)
  #joblib.dump(best_model, 'oPPG_Lasso.pkl')
  return best_model

# %%
def Elastic_tune(X_train, y_train, cv_choice, num_trials, timeout_choice):
  def Elastic_objective(trial, cv_runs, X_train, y_train):
    alpha = trial.suggest_float("alpha", 1e-2, 10, log=True)#1e-4, 10.0; Regularization strength
    l1_ratio = trial.suggest_float("l1_ratio", 0.0, 1.0)  # Mixing ratio between Lasso and Ridge
    max_iter = trial.suggest_int("max_iter", 1000, 10000, step=100)  # Max iterations
    tol = trial.suggest_float("tol", 1e-5, 1e-2, log=True)  # Tolerance for stopping criteria

    model = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, max_iter=max_iter, tol=tol, random_state=28)
    score = cross_val_score(model, X_train, y_train, cv=cv_runs, scoring="neg_root_mean_squared_error").mean()
    return -score  # Minimize the MSE

  study = optuna.create_study(direction="minimize")
  study.optimize(lambda trial: Elastic_objective(trial, cv_choice, X_train, y_train), n_trials=num_trials, timeout=timeout_choice)

  print("Best trial:")
  trial = study.best_trial
  print(f"  Params: {trial.params}")

  best_model = ElasticNet(**trial.params, random_state=28)
  best_model.fit(X_train, y_train)
  #joblib.dump(best_model, 'EST DEF RTG_Elastic.pkl')
  return best_model

# %%
def RF_tune(X_train, y_train, cv_choice, num_trials, timeout_choice):
  def RF_objective(trial, cv_runs, X_train, y_train):
    n_estimators = trial.suggest_int('n_estimators', 45, 100)#300)
    max_depth = trial.suggest_int('max_depth', 5, 45) #50
    min_samples_split = trial.suggest_int('min_samples_split', 10, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)
    max_features = trial.suggest_categorical('max_features', ['sqrt', 'log2', None])

    model = RandomForestRegressor(n_estimators=n_estimators, max_depth=max_depth,
        min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf,
        max_features=max_features, random_state=28, n_jobs=-1)

    scores = cross_val_score(model, X_train, y_train, cv=cv_runs, scoring='neg_root_mean_squared_error', n_jobs=-1)
    mean_score = np.mean(scores)
    return -mean_score

  study = optuna.create_study(direction='minimize')
  study.optimize(lambda trial: RF_objective(trial, cv_choice, X_train, y_train), n_trials=num_trials, timeout=timeout_choice)
  print("Best parameters:", study.best_params)

  best_model = RandomForestRegressor(
      n_estimators=study.best_params['n_estimators'], max_depth=study.best_params['max_depth'],
      min_samples_split=study.best_params['min_samples_split'], min_samples_leaf=study.best_params['min_samples_leaf'],
      max_features=study.best_params['max_features'], random_state=28, n_jobs=-1)
  best_model.fit(X_train, y_train)
  #joblib.dump(best_model, 'EST OFF RTG_RF.pkl')
  return best_model

# %% [markdown]
# # **ML Algorithms**

# %%
def RLE_Model(xTrain, xTest, yTrain, yTest, choice, predict_df, tar_sca): #Function to run Ridge, Lasso, or ElasticNet model
  if(choice=="Ridge"):
    pipeline = Ridge_tune(xTrain, yTrain, 10, 1000, 20)

  if(choice=="Lasso"):
    pipeline = Lasso_tune(xTrain, yTrain, 10, 150, 10)

  if(choice=="Elastic"):
    pipeline = Elastic_tune(xTrain, yTrain, 10, 300, 10)

  modelResults = Predict_Scores(pipeline, xTrain, xTest, yTrain, yTest, tar_sca)
  #print(f'Chosen alpha  {pipeline.steps[0][1].alpha_:.6f}')
  #print(f'Intercept (b) {pipeline.steps[0][1].intercept_:.6f}')
  #print(pd.Series(pipeline.steps[0][1].coef_, index=X.columns),'\n')
  return modelResults

# %%
from sklearn.ensemble import RandomForestRegressor
def RF_model(xTrain, xTest, yTrain, yTest, predict_df, tar_sca):
  model = RF_tune(xTrain, yTrain, 5, 200, 10)
  modelResults = Predict_Scores(model, xTrain, xTest, yTrain, yTest, tar_sca)
  return modelResults

# %% [markdown]
# # **Inputs/LOOCV Function**

# %%
from joblib import Parallel, delayed
def corr_matrix_reduce(x_train, x_test):
  def compute_corr_row(i, data):
      return [data.iloc[:, i].corr(data.iloc[:, j]) for j in range(data.shape[1])]

  correlation_matrix = Parallel(n_jobs=-1)(
      delayed(compute_corr_row)(i, x_train) for i in range(x_train.shape[1])
  )

  correlation_matrix = pd.DataFrame(correlation_matrix, columns=x_train.columns, index=x_train.columns)

  # Step 2: Reduce features based on correlation threshold
  def reduce_features(corr_matrix, threshold=0.9):
    #Reduce features by removing one feature from any pair with a correlation above the threshold.
      to_drop = set()
      for i in range(corr_matrix.shape[0]):
          for j in range(i + 1, corr_matrix.shape[1]):
              if abs(corr_matrix.iloc[i, j]) > threshold:
                  # Add the second feature to the drop list
                  to_drop.add(corr_matrix.columns[j])
      return to_drop

  threshold = 0.9
  features_to_drop = reduce_features(correlation_matrix, threshold)

  # Drop the features from the original dataset
  x_train_reduced = x_train.drop(columns=features_to_drop)
  if x_test.empty != True:
    x_test = x_test.drop(columns=features_to_drop)

  # Step 3: Print results
  print("Original features:", x_train.shape[1])
  print("Features to drop:", len(features_to_drop))
  print("Reduced features:", x_train_reduced.shape[1])
  return x_train_reduced, x_test

# %%
from sklearn.datasets import make_swiss_roll
from sklearn.manifold import LocallyLinearEmbedding
from sklearn.decomposition import PCA
from sklearn.cross_decomposition import PLSRegression
def reduce_df(x_tr, x_te, y_tr, reduction_choice, if_final):
  if reduction_choice == "PLS":
    pls = PLSRegression(n_components=3)
    X_tr_pls = pls.fit_transform(x_tr, y_tr)[0]  #Extract transformed features
    if x_te.empty:
      X_te_pls = pd.DataFrame(columns=["PLS1", "PLS2", "PLS3"])  #Create empty DataFrame with correct columns if x_te is empty
    else:
      X_te_pls = pls.transform(x_te)
    X_tr_pls = pd.DataFrame(X_tr_pls, columns=["PLS1", "PLS2", "PLS3"])
    X_te_pls = pd.DataFrame(X_te_pls, columns=["PLS1", "PLS2", "PLS3"])
    #print("Explained variance in X:", np.round(pls.x_scores_.var(axis=0) / x_tr.var(axis=0).sum(), 3))
    #print("Explained variance in Y:", np.round(pls.y_scores_.var(axis=0) / y_tr.var(), 3))
    return X_tr_pls, X_te_pls, pls

  if reduction_choice == "PCA":
    pca=PCA(n_components = 3, random_state=28) #n_components = None, 420
    X_tr_PCA = pca.fit_transform(x_tr)
    if if_final == "no":
      X_te_PCA = pca.transform(x_te)
    else:
      X_te_PCA = x_te
    #print("Principal axes:\n", pca.components_.tolist())
    #print("Explained variance:\n", pca.explained_variance_.tolist())
    print("Mean:", pca.mean_)
    return X_tr_PCA, X_te_PCA, pca

# %%
def get_inputs(data_frame, y, tr_index, te_index, scaler_choice, thresh, if_final):
#Feature Importance:
  if scaler_choice == "MMS":
    scaler = MinMaxScaler()
    scaler2 = MinMaxScaler()
  else:
    scaler = StandardScaler()
    scaler2 = StandardScaler()

  if if_final == 'yes':
    data_scaled_train, data_scaled_test, y_train, y_test = data_frame, pd.DataFrame(), y, pd.DataFrame()
  else:
    data_scaled_train, data_scaled_test, y_train, y_test = data_frame.iloc[tr_index], data_frame.iloc[[te_index]], y.iloc[tr_index], y.iloc[te_index]

  train_scaled = pd.DataFrame(scaler.fit_transform(data_scaled_train), columns = data_frame.columns)
  # SOS_train_scaled = train_scaled.mul(train_scaled["SOS_Use_"], axis=0)
  # SOS_train_scaled = SOS_train_scaled.add_suffix('tim_SOS_Use')
  # train_scaled = pd.concat([train_scaled, SOS_train_scaled], axis=1)
  y_train = pd.Series(scaler2.fit_transform(y_train.values.reshape(-1, 1)).flatten())
  train_scaled_correlated, correlations_df = correlation(train_scaled, thresh, y_train) #
  train_scaled_correlated = pd.DataFrame(train_scaled_correlated)

  # prev_train_scaled_correlated = train_scaled_correlated
  # most_corr = correlations_df.columns[0]
  # second_most_corr = correlations_df.columns[1]
  # most_corr_train = prev_train_scaled_correlated.mul(train_scaled_correlated[most_corr], axis=0)
  # most_corr_train = most_corr_train.add_suffix("*")
  # most_corr_train = most_corr_train.add_suffix(most_corr)
  # train_scaled_correlated = pd.concat([train_scaled_correlated, most_corr_train], axis=1)
  train_scaled_correlated, correlations_df = correlation(train_scaled_correlated, thresh, y_train)

  if if_final == 'no':
    y_test = pd.Series(y_test)
    y_test = y_test.values.reshape(-1, 1)
    y_test = scaler2.transform(y_test).flatten()
    test_scaled = pd.DataFrame(scaler.transform(data_scaled_test), columns=data_frame.columns)
    # SOS_test_scaled = test_scaled.mul(test_scaled["SOS_Use_"], axis=0)
    # SOS_test_scaled = SOS_test_scaled.add_suffix('tim_SOS_Use')
    # test_scaled = pd.concat([test_scaled, SOS_test_scaled], axis=1)

    # prev_test_scaled = test_scaled
    # most_corr_test = prev_test_scaled.mul(test_scaled[most_corr], axis=0)
    # most_corr_test = most_corr_test.add_suffix("*")
    # most_corr_test = most_corr_test.add_suffix(most_corr)
    # test_scaled = pd.concat([test_scaled, most_corr_test], axis=1)
    test_scaled_correlated = test_scaled.loc[:, train_scaled_correlated.columns] #Test data with only correlated inputs
  else:
    test_scaled_correlated = data_scaled_test

  train_scaled_correlated, test_scaled_correlated = corr_matrix_reduce(train_scaled_correlated, test_scaled_correlated)
  correlations_df2 = correlations_df.loc[:, train_scaled_correlated.columns]

  return train_scaled_correlated, test_scaled_correlated, scaler, scaler2, y_train, y_test, correlations_df#,correlations_df2

# %%
def reduce_and_model(X_tr_reduced, X_te_reduced, Y_tr, Y_te, reduction_choice, scaler_target, is_final_model, model_choice):
  if reduction_choice == 'PLS':
    X_tr_reduced, X_te_reduced, PLS_reducer = reduce_df(X_tr_reduced, X_te_reduced, Y_tr, "PLS", is_final_model)
  elif reduction_choice == 'PCA':
    X_tr_reduced, X_te_reduced, PCA_reducer = reduce_df(X_tr_reduced, X_te_reduced, Y_tr, "PCA", is_final_model)

  if model_choice == 'Ridge':
    model = RLE_Model(X_tr_reduced, X_te_reduced, Y_tr, Y_te, "Ridge", X_te_reduced, scaler_target)
  elif model_choice == 'Lasso':
    model = RLE_Model(X_tr_reduced, X_te_reduced, Y_tr, Y_te, "Lasso", X_te_reduced, scaler_target)
  elif model_choice == 'Elastic':
    model = RLE_Model(X_tr_reduced, X_te_reduced, Y_tr, Y_te, "Elastic", X_te_reduced, scaler_target)
  elif model_choice == 'RF':
    model = RF_model(X_tr_reduced, X_te_reduced, Y_tr, Y_te, X_te_reduced, scaler_target)
  elif model_choice == 'XG':
    if not isinstance(X_tr_reduced, pd.DataFrame):
        X_tr_reduced = pd.DataFrame(X_tr_reduced)
    if not isinstance(X_te_reduced, pd.DataFrame):
        X_te_reduced = pd.DataFrame(X_te_reduced)
    X_tr_reduced.columns = X_tr_reduced.columns.astype(str).str.replace(r'[\[\]<]', 'under', regex=True)
    X_te_reduced.columns = X_te_reduced.columns.astype(str).str.replace(r'[\[\]<]', 'under', regex=True)
    model = XG_model(X_tr_reduced, X_te_reduced, Y_tr, Y_te, X_te_reduced, scaler_target)

  return model

# %%
from joblib import Parallel, delayed
from sklearn.model_selection import LeaveOneOut
# Define the function that processes each fold of LOO-CV and can make final model
def process_fold(train_index, test_index, X, y, reduce_choice, corr_thresh, scaling_choice, modeling_choice):
  if scaling_choice == "MMS":
    X_train, X_test, scalerPPG, scalerY, Y_train, Y_test, correlations_df = get_inputs(X, y, train_index, test_index[0], "MMS", corr_thresh, 'no')
  else:
    X_train, X_test, scalerPPG, scalerY, Y_train, Y_test, correlations_df = get_inputs(X, y, train_index, test_index[0], "", corr_thresh, 'no')

  common_columns = list(set(X_train.columns).intersection(correlations_df.columns))
  if not common_columns:
      # Handle the case where there are no correlated columns
      return None
  X_train_with_corrs = pd.concat([X_train[common_columns], correlations_df[common_columns]])
  X_train_with_corrs = X_train_with_corrs.transpose()
  X_train_with_corrs = X_train_with_corrs.sort_values(by='corrs', ascending = False, key=abs)
  X_train_with_corrs = X_train_with_corrs.head(100)
  X_train_reduced = X_train_with_corrs.drop('corrs', axis = 1) #drop corrs column
  X_train_reduced = X_train_reduced.transpose()
  X_train_reduced.reset_index(drop = True, inplace = True)
  X_test_reduced = pd.DataFrame(X_test, columns=X_train_reduced.columns)

  model = reduce_and_model(X_train_reduced, X_test_reduced, Y_train, Y_test, reduce_choice, scalerY, 'no', modeling_choice)

  return model #Return the model for each fold

# %% [markdown]
# # **Test 1 Fold**

# %%
X = inputs
y = playoffs['PTS_Finals/GM']
len_df = len(X)
train_index = list(range(len_df-1))
test_index = list(range((len_df-1), len_df))
X_train, X_test, scalerPPG, scalerY, Y_train, Y_test, correlations_df = get_inputs(X, y, train_index, test_index[0], "MMS", 0.46, 'no')
print(len(X_test.columns))
common_columns = list(set(X_train.columns).intersection(correlations_df.columns))
X_train_with_corrs = pd.concat([X_train[common_columns], correlations_df[common_columns]])
X_train_with_corrs = X_train_with_corrs.transpose()
X_train_with_corrs = X_train_with_corrs.sort_values(by='corrs', ascending = False, key=abs)
X_train_with_corrs = X_train_with_corrs.head(100)
X_train_reduced = X_train_with_corrs.drop('corrs', axis = 1) #drop corrs column
X_train_reduced = X_train_reduced.transpose()
X_train_reduced.reset_index(drop = True, inplace = True)
X_test_reduced = pd.DataFrame(X_test, columns=X_train_reduced.columns)
print(len(X_test_reduced.columns))

# model = reduce_and_model(X_train_reduced, X_test_reduced, Y_train, Y_test, 'none', scalerY, 'no', 'Ridge')
# print(model[3]) #test error

# %%
model = reduce_and_model(X_train_reduced, X_test_reduced, Y_train, Y_test, 'none', scalerY, 'no', 'Ridge')
print(model[3])

# %% [markdown]
# # **Run LOO-CV**

# %% [markdown]
# *   Each scaler for corr, PLS; PCA
# *   adjust tuning, only take linear corr columns, mult by top 3 most corr; run longer

# %%
X = inputs
y = playoffs['PTS_Finals/GM']
loo = LeaveOneOut()
results = Parallel(n_jobs=-1)(delayed(process_fold)(train_idx, test_idx, X, y, '', .46, 'MMS', 'Ridge') #
                              for train_idx, test_idx in loo.split(X))
train_NRMSE_scores = 0
train_NMAE_scores = 0
test_RMSE_num_error = 0
train_error = 0
test_error = 0
len_df = len(X)
y_test_preds = []
range_target = y.max() - y.min()
for i in range(len_df):
  train_NRMSE_scores = results[i][0] + train_NRMSE_scores
  train_NMAE_scores = results[i][1] + train_NMAE_scores
  train_error = results[i][2] + train_error #inv transformed
  test_error = results[i][3] + test_error #inv transformed
  test_RMSE_num_error = results[i][3]**2 + test_RMSE_num_error
  y_test_preds.append(results[i][4]) #inv transformed

test_MAE = test_error/len_df
test_RMSE = math.sqrt(test_RMSE_num_error[0]/len_df)
test_NRMSE = test_RMSE/range_target
test_NMAE = test_MAE/range_target
range_preds = max(y_test_preds) - min(y_test_preds)

print(f'AVG training Normalized RMSE: {(train_NRMSE_scores/len_df):.2f}')
print(f'AVG training Normalized MAE: {(train_NMAE_scores/len_df):.2f}')
print(f'AVG of avg inv transformed train error from folds: {(np.mean(train_error)/len_df):.1f}')
print(f'Test Normalized RMSE: {test_NRMSE:.2f}')
print(f'Test Normalized MAE: {test_NMAE.item():.2f}')
print(f'AVG inv transformed test error: {(test_error.item()/len_df):.1f}')
print(f'Range of predictions (inv transformed): {(range_preds.item()):.1f}') #make sure not predicting same value for all preds
print('Test Predictions (inv transformed):')
for value in y_test_preds:
    print(f'{value.item():.0f}')
# Out:
# AVG training Normalized RMSE: 0.09
# AVG training Normalized MAE: 0.07
# AVG of avg inv transformed train error from folds: 3.0
# Test Normalized RMSE: 0.17
# Test Normalized MAE: 0.13
# AVG inv transformed test error: 5.5
# Range of predictions (inv transformed): 20.7
# Test Predictions (inv transformed):
# 109
# 107
# 101
# 102
# 101
# 102
# 105
# 110
# 106
# 104
# 107
# 98
# 101
# 106
# 102
# 100
# 98
# 98
# 97
# 102
# 95
# 93
# 96
# 96
# 93
# 91
# 91
# 93
# 89
# 92

# %%
print(f"{range_target:.1f}")
y_test_preds_flat = np.array([pred.item() for pred in y_test_preds])  # Flatten the list of arrays
y_flat = np.array([y_flattened.item() for y_flattened in y.values])
result = y_test_preds_flat - y_flat
print(result)

# %% [markdown]
# # **PPG_Finals**

# %% [markdown]
# **Ridge MMS, .46, alpha - 1:25, TPU, max of 1000 runs and 20 seconds**
#
# *   AVG training Normalized RMSE: 0.09
# *   AVG training Normalized MAE: 0.07
# *   AVG of avg inv transformed train error from folds: 3.0
# *   Test Normalized RMSE: 0.17
# *   Test Normalized MAE: 0.13
# *   AVG inv transformed test error: 5.5
# *   Range of predictions (inv transformed): 20.7
#
# **Ridge, .46, alpha - 7: 20, PCA, max of 10 seconds and 200 runs****
# *   AVG training Normalized RMSE: 0.11
# *   AVG training Normalized MAE: 0.09
# *   AVG of avg inv transformed train error from folds: 3.6
# *   Test Normalized RMSE: 0.17
# *   Test Normalized MAE: 0.13
# *   AVG inv transformed test error: 5.5
# *   Range of predictions (inv transformed): 19.0
#
# **Elastic, MMS, .46**
#
# *   AVG training Normalized RMSE: 0.08
# *   AVG training Normalized MAE: 0.06
# *   AVG of avg inv transformed train error from folds: 2.6
# *   Test Normalized RMSE: 0.18
# *   Test Normalized MAE: 0.14
# *   AVG inv transformed test error: 5.9
# *   Range of predictions (inv transformed): 24.7

# %% [markdown]
# # **Final Model**

# %% [markdown]
# Ridge, .46, MMS, alpha - 1:25, TPU, max of 1000 runs and 20 seconds
# *   Best trial: Params: {'alpha': 9.028239456268706, 'solver': 'sag'}
# *   Normalized RMSE: 0.093
# *   Normalized MAE: 0.075
# *   avg inv transformed accuracy: 3.1
# *   Range of predictions (inv transformed): 26.8

# %%
X = inputs
y = playoffs['PTS_Finals/GM']
len_df = len(X)
train_index = list(range(len_df))
test_index = list(range(1))

X_train, X_test, scalerPPG, scalerY, Y_train, Y_test, correlations_df = get_inputs(X, y, train_index, test_index[0], "MMS", 0.46, 'yes')

common_columns = list(set(X_train.columns).intersection(correlations_df.columns))
X_train_with_corrs = pd.concat([X_train[common_columns], correlations_df[common_columns]])
X_train_with_corrs = X_train_with_corrs.transpose()
X_train_with_corrs = X_train_with_corrs.sort_values(by='corrs', ascending = False, key=abs)
X_train_with_corrs = X_train_with_corrs.head(100)
X_train_reduced = X_train_with_corrs.drop('corrs', axis = 1) #drop corrs column
X_train_reduced = X_train_reduced.transpose()
X_train_reduced.reset_index(drop = True, inplace = True)

model = reduce_and_model(X_train_reduced, X_test, Y_train, Y_test, '', scalerY, 'yes', 'Ridge')

range_preds =  model[5].max() - model[5].min() #inv transformed
print(f'Normalized RMSE: {(model[0]):.3f}')
print(f'Normalized MAE: {(model[1]):.3f}')
print(f'avg inv transformed accuracy: {(np.mean(model[2])):.1f}')
print(f'Range of predictions (inv transformed): {(range_preds):.1f}') #make sure not predicting same value for all preds
print('inv transformed predictions:')
for value in model[5]:
    print(f'{value:.2f}')
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py:2922: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.11/dist-packages/numpy/lib/_function_base_impl.py:2923: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# [I 2025-06-04 14:54:56,374] A new study created in memory with name: no-name-db4574d6-297f-498c-a9bd-fe7c48b99fbe
# [I 2025-06-04 14:54:56,432] Trial 0 finished with value: 0.12635620955697266 and parameters: {'alpha': 7.361084358818593, 'solver': 'sag'}. Best is trial 0 with value: 0.12635620955697266.
# [I 2025-06-04 14:54:56,476] Trial 1 finished with value: 0.12630004124082056 and parameters: {'alpha': 7.679485769896476, 'solver': 'svd'}. Best is trial 1 with value: 0.12630004124082056.
# [I 2025-06-04 14:54:56,518] Trial 2 finished with value: 0.12753067110055014 and parameters: {'alpha': 4.895475044037765, 'solver': 'svd'}. Best is trial 1 with value: 0.12630004124082056.
# [I 2025-06-04 14:54:56,561] Trial 3 finished with value: 0.126982672601403 and parameters: {'alpha': 5.669205991345835, 'solver': 'svd'}. Best is trial 1 with value: 0.12630004124082056.
# Original features: 449
# Features to drop: 318
# Reduced features: 131
# [I 2025-06-04 14:54:56,604] Trial 4 finished with value: 0.13595148596365497 and parameters: {'alpha': 1.3508775942285935, 'solver': 'svd'}. Best is trial 1 with value: 0.12630004124082056.
# [I 2025-06-04 14:54:56,667] Trial 5 finished with value: 0.13247951217742307 and parameters: {'alpha': 2.159184696844063, 'solver': 'saga'}. Best is trial 1 with value: 0.12630004124082056.
# [I 2025-06-04 14:54:56,709] Trial 6 finished with value: 0.1267466972209096 and parameters: {'alpha': 6.130058446059465, 'solver': 'sparse_cg'}. Best is trial 1 with value: 0.12630004124082056.
# [I 2025-06-04 14:54:56,752] Trial 7 finished with value: 0.12678436296719758 and parameters: {'alpha': 6.0484481359552955, 'solver': 'cholesky'}. Best is trial 1 with value: 0.12630004124082056.
# [I 2025-06-04 14:54:56,800] Trial 8 finished with value: 0.12628039121916093 and parameters: {'alpha': 10.38436657274186, 'solver': 'sag'}. Best is trial 8 with value: 0.12628039121916093.
# [I 2025-06-04 14:54:56,845] Trial 9 finished with value: 0.13807131845441942 and parameters: {'alpha': 1.0039665080840616, 'solver': 'lsqr'}. Best is trial 8 with value: 0.12628039121916093.
# [I 2025-06-04 14:54:56,896] Trial 10 finished with value: 0.13003565221850016 and parameters: {'alpha': 24.220171255165873, 'solver': 'sag'}. Best is trial 8 with value: 0.12628039121916093.
# [I 2025-06-04 14:54:56,943] Trial 11 finished with value: 0.12726239216006882 and parameters: {'alpha': 15.2501955793888, 'solver': 'auto'}. Best is trial 8 with value: 0.12628039121916093.
# [I 2025-06-04 14:54:56,995] Trial 12 finished with value: 0.12657965300753604 and parameters: {'alpha': 12.34719555220769, 'solver': 'sag'}. Best is trial 8 with value: 0.12628039121916093.
# [I 2025-06-04 14:54:57,039] Trial 13 finished with value: 0.12638525671538312 and parameters: {'alpha': 11.219970823645388, 'solver': 'sparse_cg'}. Best is trial 8 with value: 0.12628039121916093.
# [I 2025-06-04 14:54:57,083] Trial 14 finished with value: 0.13103348290666172 and parameters: {'alpha': 2.646317430647073, 'solver': 'cholesky'}. Best is trial 8 with value: 0.12628039121916093.
# [I 2025-06-04 14:54:57,145] Trial 15 finished with value: 0.12938061908690696 and parameters: {'alpha': 3.4176294713188, 'solver': 'saga'}. Best is trial 8 with value: 0.12628039121916093.
# [I 2025-06-04 14:54:57,188] Trial 16 finished with value: 0.1262045641397382 and parameters: {'alpha': 9.115295233776404, 'solver': 'auto'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,232] Trial 17 finished with value: 0.12870353939339327 and parameters: {'alpha': 20.109287567729133, 'solver': 'auto'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,276] Trial 18 finished with value: 0.1265011443293243 and parameters: {'alpha': 11.931606578244335, 'solver': 'auto'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,325] Trial 19 finished with value: 0.1262052607224457 and parameters: {'alpha': 8.940994517565779, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,374] Trial 20 finished with value: 0.1279080102552637 and parameters: {'alpha': 17.526203586938074, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,423] Trial 21 finished with value: 0.12621021054257364 and parameters: {'alpha': 9.368222755990645, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,473] Trial 22 finished with value: 0.12620597290506003 and parameters: {'alpha': 8.87533330066818, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,524] Trial 23 finished with value: 0.12625495639343223 and parameters: {'alpha': 8.036063069089131, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,576] Trial 24 finished with value: 0.1284845654222176 and parameters: {'alpha': 4.004483065648839, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,621] Trial 25 finished with value: 0.12715029452170717 and parameters: {'alpha': 14.825020488393777, 'solver': 'auto'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,667] Trial 26 finished with value: 0.1262063363931119 and parameters: {'alpha': 8.851342320531046, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,713] Trial 27 finished with value: 0.1276682004448579 and parameters: {'alpha': 4.739596690178755, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,758] Trial 28 finished with value: 0.12646370579821678 and parameters: {'alpha': 6.9150165926094385, 'solver': 'auto'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,805] Trial 29 finished with value: 0.12949770476635686 and parameters: {'alpha': 3.3520193743043927, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,850] Trial 30 finished with value: 0.12668944572498936 and parameters: {'alpha': 12.888203155055232, 'solver': 'sparse_cg'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,897] Trial 31 finished with value: 0.12620606423252426 and parameters: {'alpha': 8.868946459848685, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,942] Trial 32 finished with value: 0.12643378738608954 and parameters: {'alpha': 7.038645841490459, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:57,988] Trial 33 finished with value: 0.12620700589433204 and parameters: {'alpha': 8.814387507906, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,036] Trial 34 finished with value: 0.1263229677943321 and parameters: {'alpha': 7.55268379979143, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,080] Trial 35 finished with value: 0.12764844449636326 and parameters: {'alpha': 4.762076403772308, 'solver': 'cholesky'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,127] Trial 36 finished with value: 0.12628880421191085 and parameters: {'alpha': 10.477887039228303, 'solver': 'svd'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,180] Trial 37 finished with value: 0.1269886217938661 and parameters: {'alpha': 14.188653385988825, 'solver': 'saga'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,225] Trial 38 finished with value: 0.12678591121866084 and parameters: {'alpha': 6.045164314438006, 'solver': 'auto'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,272] Trial 39 finished with value: 0.12716594230610523 and parameters: {'alpha': 5.375400821649298, 'solver': 'svd'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,319] Trial 40 finished with value: 0.1281592815263589 and parameters: {'alpha': 18.360206566284255, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,365] Trial 41 finished with value: 0.1262055769224358 and parameters: {'alpha': 8.907103214271439, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,415] Trial 42 finished with value: 0.1262052340096903 and parameters: {'alpha': 9.103768740691118, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,476] Trial 43 finished with value: 0.12625061344054625 and parameters: {'alpha': 10.073840559525378, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,527] Trial 44 finished with value: 0.12659894769181518 and parameters: {'alpha': 6.49311887825335, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,581] Trial 45 finished with value: 0.1262419180310642 and parameters: {'alpha': 8.158028634920628, 'solver': 'sag'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,636] Trial 46 finished with value: 0.1266539044731815 and parameters: {'alpha': 12.720859595711028, 'solver': 'saga'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,683] Trial 47 finished with value: 0.12625545392881382 and parameters: {'alpha': 10.132830391248712, 'solver': 'sparse_cg'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,729] Trial 48 finished with value: 0.13316588901189036 and parameters: {'alpha': 1.965662268787771, 'solver': 'cholesky'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,774] Trial 49 finished with value: 0.12633795678617382 and parameters: {'alpha': 7.457248279762822, 'solver': 'auto'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,821] Trial 50 finished with value: 0.12717746089683968 and parameters: {'alpha': 5.357563739159862, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,869] Trial 51 finished with value: 0.12620558537274343 and parameters: {'alpha': 8.9063335292429, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,915] Trial 52 finished with value: 0.12643894908135256 and parameters: {'alpha': 11.575938064503818, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:58,962] Trial 53 finished with value: 0.12622238739825178 and parameters: {'alpha': 9.659782333771506, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,011] Trial 54 finished with value: 0.1262665475971748 and parameters: {'alpha': 7.933956858208584, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,063] Trial 55 finished with value: 0.12756524799551852 and parameters: {'alpha': 16.347251037949928, 'solver': 'sag'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,110] Trial 56 finished with value: 0.12957974457607352 and parameters: {'alpha': 22.82924867660653, 'solver': 'svd'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,160] Trial 57 finished with value: 0.1268244322822945 and parameters: {'alpha': 13.500318508173493, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,205] Trial 58 finished with value: 0.12634968878343078 and parameters: {'alpha': 10.975475828853604, 'solver': 'auto'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,252] Trial 59 finished with value: 0.12660424367377415 and parameters: {'alpha': 6.478662629381644, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,300] Trial 60 finished with value: 0.12830767521315106 and parameters: {'alpha': 4.143166559857645, 'solver': 'sparse_cg'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,349] Trial 61 finished with value: 0.12620913918894378 and parameters: {'alpha': 8.72654763425763, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,404] Trial 62 finished with value: 0.12620506085941682 and parameters: {'alpha': 9.074713458823414, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,456] Trial 63 finished with value: 0.1264480774363554 and parameters: {'alpha': 11.630992939166095, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,509] Trial 64 finished with value: 0.1264339679612808 and parameters: {'alpha': 7.037947385226727, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,560] Trial 65 finished with value: 0.12688564212539 and parameters: {'alpha': 5.844471412024926, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,606] Trial 66 finished with value: 0.1262347215145992 and parameters: {'alpha': 8.238507193582791, 'solver': 'cholesky'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,669] Trial 67 finished with value: 0.12621665703968513 and parameters: {'alpha': 9.567451709753733, 'solver': 'saga'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,717] Trial 68 finished with value: 0.12620862822683926 and parameters: {'alpha': 9.337253033360819, 'solver': 'auto'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,768] Trial 69 finished with value: 0.12726878722392523 and parameters: {'alpha': 15.275138350740782, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,816] Trial 70 finished with value: 0.1265099001267263 and parameters: {'alpha': 6.7631889905079925, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,869] Trial 71 finished with value: 0.12622076244642205 and parameters: {'alpha': 8.455104582757638, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,917] Trial 72 finished with value: 0.12631877891656773 and parameters: {'alpha': 10.733614610348019, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:54:59,964] Trial 73 finished with value: 0.12631736927701157 and parameters: {'alpha': 7.585339153990805, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:55:00,012] Trial 74 finished with value: 0.12620503414117654 and parameters: {'alpha': 9.068599792969374, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:55:00,058] Trial 75 finished with value: 0.12653527386089183 and parameters: {'alpha': 12.1233505527741, 'solver': 'lsqr'}. Best is trial 16 with value: 0.1262045641397382.
# [I 2025-06-04 14:55:00,112] Trial 76 finished with value: 0.1262038714235219 and parameters: {'alpha': 9.066909918432607, 'solver': 'sag'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,164] Trial 77 finished with value: 0.12635005552659048 and parameters: {'alpha': 10.963953925731483, 'solver': 'sag'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,216] Trial 78 finished with value: 0.12622099046084348 and parameters: {'alpha': 9.627098103302291, 'solver': 'sag'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,268] Trial 79 finished with value: 0.12691757033235615 and parameters: {'alpha': 13.893476683050729, 'solver': 'sag'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,321] Trial 80 finished with value: 0.12632598368564885 and parameters: {'alpha': 7.51817223785802, 'solver': 'sag'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,367] Trial 81 finished with value: 0.12620441287103928 and parameters: {'alpha': 9.095783658554684, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,410] Trial 82 finished with value: 0.12620415160483528 and parameters: {'alpha': 9.019946137941433, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,455] Trial 83 finished with value: 0.12626230919515316 and parameters: {'alpha': 10.213488596052748, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,499] Trial 84 finished with value: 0.12624725906436346 and parameters: {'alpha': 8.099208211275064, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,544] Trial 85 finished with value: 0.12659569166628015 and parameters: {'alpha': 6.502683450027011, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,589] Trial 86 finished with value: 0.12667694802689627 and parameters: {'alpha': 12.830462284003842, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,633] Trial 87 finished with value: 0.12640944952774594 and parameters: {'alpha': 7.123308791781699, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,678] Trial 88 finished with value: 0.1262063375431191 and parameters: {'alpha': 9.240634662886498, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,725] Trial 89 finished with value: 0.12628674140293095 and parameters: {'alpha': 10.458732490774942, 'solver': 'svd'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,770] Trial 90 finished with value: 0.12645599117989614 and parameters: {'alpha': 11.67186549151087, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,814] Trial 91 finished with value: 0.12620499957968936 and parameters: {'alpha': 8.885280600959655, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,858] Trial 92 finished with value: 0.12621966686443414 and parameters: {'alpha': 8.456526023904091, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,905] Trial 93 finished with value: 0.13542966359929204 and parameters: {'alpha': 1.4498658039416612, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:00,952] Trial 94 finished with value: 0.1262426055997487 and parameters: {'alpha': 9.979693206499114, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,012] Trial 95 finished with value: 0.12627748999001273 and parameters: {'alpha': 7.83514531260223, 'solver': 'saga'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,061] Trial 96 finished with value: 0.12620517053893174 and parameters: {'alpha': 9.17834004956323, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,110] Trial 97 finished with value: 0.12667795467310777 and parameters: {'alpha': 6.287725234746491, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,160] Trial 98 finished with value: 0.12715420586514053 and parameters: {'alpha': 5.393347141602547, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,207] Trial 99 finished with value: 0.12620578790667278 and parameters: {'alpha': 9.217050199379997, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,262] Trial 100 finished with value: 0.12637151657283852 and parameters: {'alpha': 11.125455961002672, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,312] Trial 101 finished with value: 0.12621308487736768 and parameters: {'alpha': 8.589357482956567, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,359] Trial 102 finished with value: 0.12639367993865916 and parameters: {'alpha': 7.190072331746667, 'solver': 'cholesky'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,412] Trial 103 finished with value: 0.12622409673623358 and parameters: {'alpha': 9.679713311223834, 'solver': 'sag'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,458] Trial 104 finished with value: 0.12626717123273642 and parameters: {'alpha': 7.918095809123754, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,503] Trial 105 finished with value: 0.1262051403122275 and parameters: {'alpha': 8.865056750163747, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,548] Trial 106 finished with value: 0.12654508388892527 and parameters: {'alpha': 12.168893699265675, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,596] Trial 107 finished with value: 0.12628828932350605 and parameters: {'alpha': 10.46502693946843, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,642] Trial 108 finished with value: 0.12620404843188027 and parameters: {'alpha': 9.040681061188888, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,688] Trial 109 finished with value: 0.12622230915751986 and parameters: {'alpha': 8.409084111089955, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,735] Trial 110 finished with value: 0.12631698693832255 and parameters: {'alpha': 7.573114475273999, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,781] Trial 111 finished with value: 0.12620409926089343 and parameters: {'alpha': 9.058930685048642, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,827] Trial 112 finished with value: 0.12620467098227095 and parameters: {'alpha': 9.138396189515769, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,873] Trial 113 finished with value: 0.12625031049020324 and parameters: {'alpha': 10.072019515179653, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,918] Trial 114 finished with value: 0.1262044073129214 and parameters: {'alpha': 8.928920085826148, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:01,965] Trial 115 finished with value: 0.12650454072118097 and parameters: {'alpha': 6.773429663388437, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,014] Trial 116 finished with value: 0.12635979598344158 and parameters: {'alpha': 11.042317822266918, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,061] Trial 117 finished with value: 0.12625134496275112 and parameters: {'alpha': 8.056684052563803, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,108] Trial 118 finished with value: 0.1262190654882264 and parameters: {'alpha': 9.598228543262959, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,156] Trial 119 finished with value: 0.1262081008487856 and parameters: {'alpha': 8.726298769295418, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,207] Trial 120 finished with value: 0.1263841959338658 and parameters: {'alpha': 7.230257181769024, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,257] Trial 121 finished with value: 0.12620660273128476 and parameters: {'alpha': 9.258978704847323, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,303] Trial 122 finished with value: 0.12620652114955583 and parameters: {'alpha': 8.789293235450653, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,350] Trial 123 finished with value: 0.12627677186293504 and parameters: {'alpha': 10.354089806773276, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,396] Trial 124 finished with value: 0.12622998264958696 and parameters: {'alpha': 8.29670121924201, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,442] Trial 125 finished with value: 0.12642243784954324 and parameters: {'alpha': 11.467286639540829, 'solver': 'svd'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,488] Trial 126 finished with value: 0.12623256483033762 and parameters: {'alpha': 9.833475677694047, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,533] Trial 127 finished with value: 0.12630069024211887 and parameters: {'alpha': 7.6752887104132, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,587] Trial 128 finished with value: 0.12620580705027795 and parameters: {'alpha': 9.165411485713703, 'solver': 'sag'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,632] Trial 129 finished with value: 0.1266130595418207 and parameters: {'alpha': 12.51852111798426, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,700] Trial 130 finished with value: 0.1308694678636259 and parameters: {'alpha': 2.711134965999219, 'solver': 'saga'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,747] Trial 131 finished with value: 0.1262050512256693 and parameters: {'alpha': 9.16100370527772, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,791] Trial 132 finished with value: 0.12629949643940813 and parameters: {'alpha': 10.574131889027322, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,836] Trial 133 finished with value: 0.1262352560916199 and parameters: {'alpha': 8.231990017703765, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,881] Trial 134 finished with value: 0.12620424583511375 and parameters: {'alpha': 8.974953055630298, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,926] Trial 135 finished with value: 0.12624017206167912 and parameters: {'alpha': 9.947382705133748, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:02,970] Trial 136 finished with value: 0.12621382632631228 and parameters: {'alpha': 8.57225331588986, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:03,014] Trial 137 finished with value: 0.12629777372730858 and parameters: {'alpha': 7.694279183411442, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:03,058] Trial 138 finished with value: 0.12635601039464767 and parameters: {'alpha': 11.021622174844142, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:03,103] Trial 139 finished with value: 0.12621408795264646 and parameters: {'alpha': 9.496416232662087, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:03,149] Trial 140 finished with value: 0.12620636560963389 and parameters: {'alpha': 8.803192134839955, 'solver': 'cholesky'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:03,195] Trial 141 finished with value: 0.12620540903872998 and parameters: {'alpha': 9.186905060389753, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:03,241] Trial 142 finished with value: 0.12623896044476515 and parameters: {'alpha': 8.186140951752177, 'solver': 'sparse_cg'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:03,286] Trial 143 finished with value: 0.12626620018947887 and parameters: {'alpha': 10.255202576304814, 'solver': 'auto'}. Best is trial 76 with value: 0.1262038714235219.
# [I 2025-06-04 14:55:03,338] Trial 144 finished with value: 0.1262038087749593 and parameters: {'alpha': 8.998983555885394, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,393] Trial 145 finished with value: 0.12642986498325123 and parameters: {'alpha': 7.041384000751076, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,446] Trial 146 finished with value: 0.1263396280406456 and parameters: {'alpha': 7.443292140438365, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,499] Trial 147 finished with value: 0.12622355376755928 and parameters: {'alpha': 9.676364794733253, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,552] Trial 148 finished with value: 0.12620622917251245 and parameters: {'alpha': 8.778610633162996, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,600] Trial 149 finished with value: 0.12626091638315215 and parameters: {'alpha': 7.971031154575448, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,645] Trial 150 finished with value: 0.1264453080404006 and parameters: {'alpha': 11.607923732611996, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,690] Trial 151 finished with value: 0.12620564904368264 and parameters: {'alpha': 9.209014639650455, 'solver': 'sparse_cg'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,737] Trial 152 finished with value: 0.12630743339720224 and parameters: {'alpha': 10.633819251960036, 'solver': 'sparse_cg'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,783] Trial 153 finished with value: 0.12620415394969164 and parameters: {'alpha': 9.027257699165018, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,830] Trial 154 finished with value: 0.12624100918600129 and parameters: {'alpha': 9.958605819467339, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,880] Trial 155 finished with value: 0.12622697740649802 and parameters: {'alpha': 8.340867383641003, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,928] Trial 156 finished with value: 0.1262062918081111 and parameters: {'alpha': 8.806797280281282, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:03,974] Trial 157 finished with value: 0.12627450630238068 and parameters: {'alpha': 7.859646414247277, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,027] Trial 158 finished with value: 0.1262171768633987 and parameters: {'alpha': 9.545964088499938, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,072] Trial 159 finished with value: 0.12631250373641878 and parameters: {'alpha': 10.685234730260017, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,128] Trial 160 finished with value: 0.12621128812528357 and parameters: {'alpha': 8.6201788492899, 'solver': 'saga'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,174] Trial 161 finished with value: 0.12620486809493325 and parameters: {'alpha': 9.155533353262088, 'solver': 'sparse_cg'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,220] Trial 162 finished with value: 0.12620852420513645 and parameters: {'alpha': 9.337262397204642, 'solver': 'sparse_cg'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,265] Trial 163 finished with value: 0.12623564942032475 and parameters: {'alpha': 9.88457664553704, 'solver': 'cholesky'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,309] Trial 164 finished with value: 0.12622187460212947 and parameters: {'alpha': 8.419001319412049, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,355] Trial 165 finished with value: 0.1263607659330007 and parameters: {'alpha': 7.339480204113117, 'solver': 'sparse_cg'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,410] Trial 166 finished with value: 0.12625138181621468 and parameters: {'alpha': 8.054449446583002, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,459] Trial 167 finished with value: 0.12620417739914921 and parameters: {'alpha': 9.043825507920786, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,508] Trial 168 finished with value: 0.1262441945607963 and parameters: {'alpha': 10.000292622524018, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,555] Trial 169 finished with value: 0.12651174518730174 and parameters: {'alpha': 6.752187343310565, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,601] Trial 170 finished with value: 0.12620674225203324 and parameters: {'alpha': 9.260425813197184, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,649] Trial 171 finished with value: 0.1262046765510875 and parameters: {'alpha': 8.913866197210016, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,696] Trial 172 finished with value: 0.12620653242275245 and parameters: {'alpha': 8.795263536088969, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,744] Trial 173 finished with value: 0.1262748466152903 and parameters: {'alpha': 7.857019891981742, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,791] Trial 174 finished with value: 0.12627944448747058 and parameters: {'alpha': 10.389260619344032, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,838] Trial 175 finished with value: 0.12621295554288595 and parameters: {'alpha': 9.467809737422078, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,885] Trial 176 finished with value: 0.1379238572102895 and parameters: {'alpha': 1.0254924646996397, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,931] Trial 177 finished with value: 0.1262277209551928 and parameters: {'alpha': 8.330296975292029, 'solver': 'svd'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:04,977] Trial 178 finished with value: 0.12636550602310884 and parameters: {'alpha': 11.089503513284487, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,022] Trial 179 finished with value: 0.1262044897003089 and parameters: {'alpha': 9.106240389072978, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,067] Trial 180 finished with value: 0.12620450329281652 and parameters: {'alpha': 9.107962473947492, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,112] Trial 181 finished with value: 0.12620418886585122 and parameters: {'alpha': 9.048619875452552, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,160] Trial 182 finished with value: 0.12624654693405168 and parameters: {'alpha': 10.030123924968809, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,205] Trial 183 finished with value: 0.12620539484781 and parameters: {'alpha': 8.857095963960523, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,249] Trial 184 finished with value: 0.1262239359339367 and parameters: {'alpha': 8.386153515288292, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,297] Trial 185 finished with value: 0.12622528593751284 and parameters: {'alpha': 9.722625268346158, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,342] Trial 186 finished with value: 0.1263270283958512 and parameters: {'alpha': 7.517054979124609, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,388] Trial 187 finished with value: 0.12620459370460083 and parameters: {'alpha': 9.118664110352109, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,432] Trial 188 finished with value: 0.12626882257954847 and parameters: {'alpha': 7.904616649211414, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,477] Trial 189 finished with value: 0.12628611266057888 and parameters: {'alpha': 10.4528534536524, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,521] Trial 190 finished with value: 0.12621079871941607 and parameters: {'alpha': 8.647374643990025, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,568] Trial 191 finished with value: 0.12620528599769298 and parameters: {'alpha': 9.178465757588375, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,613] Trial 192 finished with value: 0.12621984681911713 and parameters: {'alpha': 9.622520596867083, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,666] Trial 193 finished with value: 0.12620389589139003 and parameters: {'alpha': 8.973395644715552, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,720] Trial 194 finished with value: 0.12621281890246433 and parameters: {'alpha': 8.586802327774087, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,774] Trial 195 finished with value: 0.12624141758517549 and parameters: {'alpha': 8.163494332934695, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,829] Trial 196 finished with value: 0.12620432850643223 and parameters: {'alpha': 9.132308384025794, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,885] Trial 197 finished with value: 0.1262311957851159 and parameters: {'alpha': 9.800796607087667, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,941] Trial 198 finished with value: 0.12620635265569455 and parameters: {'alpha': 9.233266343735938, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:05,998] Trial 199 finished with value: 0.1263281358763096 and parameters: {'alpha': 10.795303408722251, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,054] Trial 200 finished with value: 0.126226713703132 and parameters: {'alpha': 8.34345977667594, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,108] Trial 201 finished with value: 0.12620521375398305 and parameters: {'alpha': 8.848336687510484, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,156] Trial 202 finished with value: 0.12621636154661983 and parameters: {'alpha': 9.549511341037384, 'solver': 'auto'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,214] Trial 203 finished with value: 0.12620383598117607 and parameters: {'alpha': 8.988846365273414, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,268] Trial 204 finished with value: 0.12623677526959315 and parameters: {'alpha': 9.885150634698602, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,322] Trial 205 finished with value: 0.12620382763708404 and parameters: {'alpha': 9.05424616919319, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,377] Trial 206 finished with value: 0.12629085194813544 and parameters: {'alpha': 7.741216080945664, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,431] Trial 207 finished with value: 0.12626849868605655 and parameters: {'alpha': 10.26299605556323, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,484] Trial 208 finished with value: 0.1262084543926219 and parameters: {'alpha': 8.705873089489229, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,539] Trial 209 finished with value: 0.12620693952739587 and parameters: {'alpha': 9.26294308773392, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,591] Trial 210 finished with value: 0.1283067985264742 and parameters: {'alpha': 18.839440500071653, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,646] Trial 211 finished with value: 0.12620394219651102 and parameters: {'alpha': 9.081916715749117, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,701] Trial 212 finished with value: 0.1262264243977576 and parameters: {'alpha': 8.347616451802189, 'solver': 'sag'}. Best is trial 144 with value: 0.1262038087749593.
# [I 2025-06-04 14:55:06,756] Trial 213 finished with value: 0.12620378371252877 and parameters: {'alpha': 9.028239456268706, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:06,810] Trial 214 finished with value: 0.1262224365308397 and parameters: {'alpha': 9.65532656353614, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:06,866] Trial 215 finished with value: 0.12839616484253788 and parameters: {'alpha': 4.070582413029901, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:06,920] Trial 216 finished with value: 0.12623242665959017 and parameters: {'alpha': 8.269450003362328, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:06,973] Trial 217 finished with value: 0.12625368078670407 and parameters: {'alpha': 10.09603334429188, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,028] Trial 218 finished with value: 0.12620416494273784 and parameters: {'alpha': 9.114380239583246, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,086] Trial 219 finished with value: 0.12628110447299756 and parameters: {'alpha': 7.810354344804545, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,142] Trial 220 finished with value: 0.12620711701261073 and parameters: {'alpha': 8.742866933474575, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,197] Trial 221 finished with value: 0.1262072321767734 and parameters: {'alpha': 9.276472945934522, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,251] Trial 222 finished with value: 0.12620960515635476 and parameters: {'alpha': 9.367540434296314, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,304] Trial 223 finished with value: 0.12620465905934816 and parameters: {'alpha': 8.886005173659317, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,357] Trial 224 finished with value: 0.12622189198337458 and parameters: {'alpha': 8.416889598465183, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,410] Trial 225 finished with value: 0.12625482271975436 and parameters: {'alpha': 10.109675748215206, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,463] Trial 226 finished with value: 0.1262037929993689 and parameters: {'alpha': 9.038054574239935, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,517] Trial 227 finished with value: 0.12623539967132164 and parameters: {'alpha': 8.23262313144871, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,570] Trial 228 finished with value: 0.12630620498469175 and parameters: {'alpha': 10.610197958734807, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,626] Trial 229 finished with value: 0.1262169880273099 and parameters: {'alpha': 9.574503139310401, 'solver': 'saga'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,680] Trial 230 finished with value: 0.12620684840403668 and parameters: {'alpha': 8.753153655728756, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,735] Trial 231 finished with value: 0.1262038124353145 and parameters: {'alpha': 9.048431233522278, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,789] Trial 232 finished with value: 0.12621050167742628 and parameters: {'alpha': 9.393377565962858, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,843] Trial 233 finished with value: 0.12620394241878083 and parameters: {'alpha': 8.964152528058845, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,897] Trial 234 finished with value: 0.12625156160301138 and parameters: {'alpha': 8.052723282561164, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:07,950] Trial 235 finished with value: 0.126210999273124 and parameters: {'alpha': 8.631724577472905, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:08,007] Trial 236 finished with value: 0.12622484683429933 and parameters: {'alpha': 9.693444665108075, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:08,061] Trial 237 finished with value: 0.12633404455414035 and parameters: {'alpha': 7.473629263514046, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:08,116] Trial 238 finished with value: 0.12620453074283416 and parameters: {'alpha': 8.896348131064844, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:08,172] Trial 239 finished with value: 0.1262044902982628 and parameters: {'alpha': 8.899792058624621, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:08,227] Trial 240 finished with value: 0.1262544028516621 and parameters: {'alpha': 10.104676935624367, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:08,282] Trial 241 finished with value: 0.12620412040598028 and parameters: {'alpha': 8.937652186069263, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:08,337] Trial 242 finished with value: 0.1262178841561062 and parameters: {'alpha': 8.486391116700199, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:08,391] Trial 243 finished with value: 0.12620557129862425 and parameters: {'alpha': 9.190334030832751, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:08,445] Trial 244 finished with value: 0.1262535063371206 and parameters: {'alpha': 8.034276720273862, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# ...
# [I 2025-06-04 14:55:12,156] Trial 313 finished with value: 0.12625222154794333 and parameters: {'alpha': 8.050336759487859, 'solver': 'cholesky'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,201] Trial 314 finished with value: 0.12620487635106575 and parameters: {'alpha': 8.895395354025045, 'solver': 'cholesky'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,248] Trial 315 finished with value: 0.12635225380055592 and parameters: {'alpha': 10.994296048147167, 'solver': 'cholesky'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,296] Trial 316 finished with value: 0.12621188381146892 and parameters: {'alpha': 9.439068666925936, 'solver': 'cholesky'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,345] Trial 317 finished with value: 0.12620834424654664 and parameters: {'alpha': 8.722882221098931, 'solver': 'svd'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,393] Trial 318 finished with value: 0.12623809196736543 and parameters: {'alpha': 9.91897111227189, 'solver': 'svd'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,439] Trial 319 finished with value: 0.12624924522560727 and parameters: {'alpha': 8.079293760883216, 'solver': 'cholesky'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,486] Trial 320 finished with value: 0.12620470907696707 and parameters: {'alpha': 9.130848547233008, 'solver': 'svd'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,540] Trial 321 finished with value: 0.1262228059688211 and parameters: {'alpha': 8.40222950119182, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,597] Trial 322 finished with value: 0.12628380061262087 and parameters: {'alpha': 10.435191183125607, 'solver': 'saga'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,653] Trial 323 finished with value: 0.12630229960658018 and parameters: {'alpha': 7.659201110771722, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,707] Trial 324 finished with value: 0.1262060646999395 and parameters: {'alpha': 9.217084583595643, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,762] Trial 325 finished with value: 0.12624366708933416 and parameters: {'alpha': 9.980195957842426, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,811] Trial 326 finished with value: 0.12621237535932747 and parameters: {'alpha': 8.606435185400086, 'solver': 'svd'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,871] Trial 327 finished with value: 0.13439061418038967 and parameters: {'alpha': 1.6651982523822706, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,925] Trial 328 finished with value: 0.12620851641489184 and parameters: {'alpha': 9.3290235907506, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:12,971] Trial 329 finished with value: 0.12620698005074368 and parameters: {'alpha': 8.775296550177762, 'solver': 'cholesky'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,025] Trial 330 finished with value: 0.1263811206585803 and parameters: {'alpha': 11.185758708105277, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,081] Trial 331 finished with value: 0.12625936679597022 and parameters: {'alpha': 7.986540490630492, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,130] Trial 332 finished with value: 0.1262352495691108 and parameters: {'alpha': 9.878831815530438, 'solver': 'svd'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,186] Trial 333 finished with value: 0.12620380145753582 and parameters: {'alpha': 9.002559985950642, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,244] Trial 334 finished with value: 0.12641132069780134 and parameters: {'alpha': 7.114258799844753, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,299] Trial 335 finished with value: 0.12623653811984253 and parameters: {'alpha': 8.219024955132406, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,353] Trial 336 finished with value: 0.12621790603691058 and parameters: {'alpha': 9.562357515666278, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,406] Trial 337 finished with value: 0.1262592215139792 and parameters: {'alpha': 10.160907389173614, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,461] Trial 338 finished with value: 0.12621273366750713 and parameters: {'alpha': 8.588795467969737, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,515] Trial 339 finished with value: 0.12620682000937108 and parameters: {'alpha': 9.257198321694824, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,571] Trial 340 finished with value: 0.1262785806924972 and parameters: {'alpha': 10.366478271429674, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,618] Trial 341 finished with value: 0.12628824478170336 and parameters: {'alpha': 7.757006233571378, 'solver': 'sparse_cg'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,673] Trial 342 finished with value: 0.1262068186073861 and parameters: {'alpha': 8.754320417893394, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,728] Trial 343 finished with value: 0.12621397977215865 and parameters: {'alpha': 9.46744742075916, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,784] Trial 344 finished with value: 0.12622682383500802 and parameters: {'alpha': 8.341884855892248, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,832] Trial 345 finished with value: 0.12620426447796204 and parameters: {'alpha': 9.069783021314265, 'solver': 'svd'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,886] Trial 346 finished with value: 0.12635686217826983 and parameters: {'alpha': 11.014261044950192, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,941] Trial 347 finished with value: 0.1263427703357674 and parameters: {'alpha': 7.426775498425673, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:13,991] Trial 348 finished with value: 0.1262255823206476 and parameters: {'alpha': 9.72073962711023, 'solver': 'sparse_cg'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,047] Trial 349 finished with value: 0.12653630276623168 and parameters: {'alpha': 12.118256463176802, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,102] Trial 350 finished with value: 0.12624140586224109 and parameters: {'alpha': 8.163622844898516, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,155] Trial 351 finished with value: 0.1268424551103569 and parameters: {'alpha': 5.929114905322689, 'solver': 'svd'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,212] Trial 352 finished with value: 0.1262040324969356 and parameters: {'alpha': 8.949520607996083, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,268] Trial 353 finished with value: 0.1262082800068905 and parameters: {'alpha': 8.71164258770963, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,322] Trial 354 finished with value: 0.1262604341634565 and parameters: {'alpha': 10.174686726394405, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,376] Trial 355 finished with value: 0.12621015286465684 and parameters: {'alpha': 9.385432619842167, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,431] Trial 356 finished with value: 0.12653691773125647 and parameters: {'alpha': 6.6775508931857095, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,489] Trial 357 finished with value: 0.1262273426340597 and parameters: {'alpha': 8.327357419323947, 'solver': 'saga'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,543] Trial 358 finished with value: 0.1262037857504732 and parameters: {'alpha': 9.014334469560056, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,600] Trial 359 finished with value: 0.12628029277513947 and parameters: {'alpha': 7.816330732480856, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,653] Trial 360 finished with value: 0.1262173078906723 and parameters: {'alpha': 9.548945196046363, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,707] Trial 361 finished with value: 0.12627636863141065 and parameters: {'alpha': 10.344352080179327, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,761] Trial 362 finished with value: 0.12620511012295504 and parameters: {'alpha': 8.854716330905681, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,816] Trial 363 finished with value: 0.1262220476082895 and parameters: {'alpha': 8.414365881720055, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,870] Trial 364 finished with value: 0.12622466765662207 and parameters: {'alpha': 9.690188168389719, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,923] Trial 365 finished with value: 0.12633812447778275 and parameters: {'alpha': 10.87390967806896, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:14,980] Trial 366 finished with value: 0.12620411872479687 and parameters: {'alpha': 9.108649060052032, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,037] Trial 367 finished with value: 0.12627069765784427 and parameters: {'alpha': 7.8898921036034055, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,092] Trial 368 finished with value: 0.12620609772727207 and parameters: {'alpha': 9.219007404334857, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,146] Trial 369 finished with value: 0.12624049213219918 and parameters: {'alpha': 9.937489218620636, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,208] Trial 370 finished with value: 0.12621711752220505 and parameters: {'alpha': 8.500843117548143, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,270] Trial 371 finished with value: 0.1300706159276005 and parameters: {'alpha': 3.055166518414929, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,325] Trial 372 finished with value: 0.12634777778897238 and parameters: {'alpha': 7.400903709213932, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,383] Trial 373 finished with value: 0.12620384769248744 and parameters: {'alpha': 9.06057505332947, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,437] Trial 374 finished with value: 0.12621205687920065 and parameters: {'alpha': 9.413085421214694, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,490] Trial 375 finished with value: 0.12629960931658585 and parameters: {'alpha': 10.559499169819578, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,544] Trial 376 finished with value: 0.12620869455499545 and parameters: {'alpha': 8.69810446337974, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,599] Trial 377 finished with value: 0.1262357970843249 and parameters: {'alpha': 9.87090364397074, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,653] Trial 378 finished with value: 0.12624605650857484 and parameters: {'alpha': 8.107310520947612, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,706] Trial 379 finished with value: 0.12681591854150506 and parameters: {'alpha': 13.459736541358527, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,754] Trial 380 finished with value: 0.12642271101221644 and parameters: {'alpha': 11.466239836581039, 'solver': 'sparse_cg'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,808] Trial 381 finished with value: 0.12620412775674855 and parameters: {'alpha': 8.936734733960916, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,862] Trial 382 finished with value: 0.12621812722533843 and parameters: {'alpha': 8.481896645201457, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,917] Trial 383 finished with value: 0.1262960267726177 and parameters: {'alpha': 7.699957677304333, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:15,972] Trial 384 finished with value: 0.12620391932938313 and parameters: {'alpha': 9.077516894380292, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:16,032] Trial 385 finished with value: 0.12622189956789925 and parameters: {'alpha': 9.644982684418743, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:16,089] Trial 386 finished with value: 0.1262400367514601 and parameters: {'alpha': 8.1787860601833, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:16,144] Trial 387 finished with value: 0.12620443704202075 and parameters: {'alpha': 8.904482731972928, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:16,199] Trial 388 finished with value: 0.12627337488747883 and parameters: {'alpha': 10.313908348246358, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:16,255] Trial 389 finished with value: 0.12620940447856935 and parameters: {'alpha': 9.360758308538236, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:16,311] Trial 390 finished with value: 0.12620959330444817 and parameters: {'alpha': 8.670632873045049, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:16,372] Trial 391 finished with value: 0.13674376146051326 and parameters: {'alpha': 1.212049883859436, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# [I 2025-06-04 14:55:16,428] Trial 392 finished with value: 0.12642339391763444 and parameters: {'alpha': 7.066857328517697, 'solver': 'sag'}. Best is trial 213 with value: 0.12620378371252877.
# Best trial:
#   Params: {'alpha': 9.028239456268706, 'solver': 'sag'}
# Normalized RMSE: 0.093
# Normalized MAE: 0.075
# avg inv transformed accuracy: 3.1
# Range of predictions (inv transformed): 26.8
# inv transformed predictions:
# 105.77
# 103.11
# 104.57
# 99.33
# 102.99
# 101.53
# 107.76
# 108.76
# 110.63
# 103.61
# 113.16
# 105.77
# 100.84
# 103.33
# 101.68
# 97.69
# 102.00
# 95.15
# 96.51
# 99.96
# 94.24
# 91.14
# 93.16
# 91.48
# 97.00
# 90.16
# 95.65
# 93.00
# 87.68
# 86.37

# %%
X = inputs
y = playoffs['PTS_Finals/GM']
len_df = len(X)
train_index = list(range(len_df))
test_index = list(range(1))

X_train, X_test, scalerPPG, scalerY, Y_train, Y_test, correlations_df = get_inputs(X, y, train_index, test_index[0], "MMS", 0.46, 'yes')

common_columns = list(set(X_train.columns).intersection(correlations_df.columns))
X_train_with_corrs = pd.concat([X_train[common_columns], correlations_df[common_columns]])
X_train_with_corrs = X_train_with_corrs.transpose()
X_train_with_corrs = X_train_with_corrs.sort_values(by='corrs', ascending = False, key=abs)
X_train_with_corrs = X_train_with_corrs.head(100)
X_train_reduced = X_train_with_corrs.drop('corrs', axis = 1) #drop corrs column
X_train_reduced = X_train_reduced.transpose()
X_train_reduced.reset_index(drop = True, inplace = True)

# %%
X_train_reduced.to_csv('PPG_Finals_Inputs.csv')

# %%
# import scipy.stats
# X = inputs
# y = playoff_stats['Pts/GM_Playoffs']#Pts/GM_Playoffs, oPts/GM_Playoffs #
# col = ''
# print(X.loc[:, col].corr(y))
# print(scipy.stats.spearmanr(X.loc[:,col], y)[0])

# %% [markdown]
# # **PPG Prediction**

# %%
X = inputs
y = playoffs['PTS_Finals/GM']
len_df = len(X)
train_index = list(range(len_df))
test_index = list(range(1))

X_train, X_test, scalerPPG, scalerY, Y_train, Y_test, correlations_df = get_inputs(X, y, train_index, test_index[0], "MMS", 0.46, 'yes')

common_columns = list(set(X_train.columns).intersection(correlations_df.columns))
X_train_with_corrs = pd.concat([X_train[common_columns], correlations_df[common_columns]])
X_train_with_corrs = X_train_with_corrs.transpose()
X_train_with_corrs = X_train_with_corrs.sort_values(by='corrs', ascending = False, key=abs)
X_train_with_corrs = X_train_with_corrs.head(100)
X_train_reduced = X_train_with_corrs.drop('corrs', axis = 1) #drop corrs column
X_train_reduced = X_train_reduced.transpose()
X_train_reduced.reset_index(drop = True, inplace = True)

# %%
X = inputs
y = playoffs['PTS_Finals/GM']
PPG_predict = pd.read_csv('PPG_Finals_Inputs.csv')
PPG_predict.columns = PPG_predict.columns.str.replace('Â\xa0', '\xa0')
PPG_predict = PPG_predict.iloc[:2,:]

PPG_scaler = MinMaxScaler()
target_scaler = MinMaxScaler()
y_train = pd.Series(target_scaler.fit_transform(y.values.reshape(-1, 1)).flatten())

trained_features_to_scale = X[PPG_predict.columns]
trained_features_scaled = pd.DataFrame(PPG_scaler.fit_transform(trained_features_to_scale), columns = trained_features_to_scale.columns)

PPG_predict_scaled = pd.DataFrame(PPG_scaler.transform(PPG_predict), columns = PPG_predict.columns)

# %%
import joblib
PPG_model = joblib.load('PPG_Ridge_Finals.pkl')
PPG_predict_scaled = PPG_predict_scaled[X_train_reduced.columns] #make sure order is correct and no extra columns
PPG_predictions = PPG_model.predict(PPG_predict_scaled)
target_scaler.inverse_transform(PPG_predictions.reshape(-1, 1))
# Out:
# array([[106.6995156 ],
#        [106.42395715]])
